# %%
import pandas as pd
import glob

folder_path = r"C:\Users\Tushar\anaconda_projects\Pandas\UIDAI HACKTHON\Hackthon\api_data_aadhar_enrolment"

csv_files = glob.glob(folder_path + "/*.csv")

df_list = [pd.read_csv(file) for file in csv_files]
combined_df = pd.concat(df_list, ignore_index=True)

combined_df.to_csv("combined_data.csv", index=False)

print("All files merged and saved as combined_data.csv")
# Out:
# All files merged and saved as combined_data.csv

# %%
df = pd.read_csv("combined_data.csv")

state_mapping = {
    "Orissa": "Odisha",
    "ODISHA": "Odisha",
    "odisha": "Odisha",
    "Tamilnadu": "Tamil Nadu",
    "Tamilnadu ": "Tamil Nadu",
    "Tamil Nadu": "Tamil Nadu",
    "Jammu & Kashmir": "Jammu and Kashmir",
    "Jammu And Kashmir": "Jammu and Kashmir",
    "Jammu and Kashmir": "Jammu and Kashmir",
    "Uttaranchal": "Uttarakhand",
    "West  Bengal": "West Bengal",
    "West Bangal": "West Bengal",
    "West bengal": "West Bengal",
    "WEST BENGAL": "West Bengal",
    "WESTBENGAL": "West Bengal",
    "west Bengal": "West Bengal",
    "Westbengal": "West Bengal",
    "Daman & Diu": "Dadra and Nagar Haveli and Daman and Diu",
    "Daman and Diu": "Dadra and Nagar Haveli and Daman and Diu",
    "Dadra & Nagar Haveli": "Dadra and Nagar Haveli and Daman and Diu",
    "Dadra and Nagar Haveli": "Dadra and Nagar Haveli and Daman and Diu",
    "dadar nager hawali and daman diu": "Dadra and Nagar Haveli and Daman and Diu",
    "Pondicherry": "Puducherry",
    "Puducherry": "Puducherry",
    "Andaman & Nicobar Islands": "Andaman and Nicobar Islands",
    "Andaman and Nicobar Islands": "Andaman and Nicobar Islands",
    "Delhi": "Delhi",
    "Chhatisgarh": "Chhattisgarh",
    "andhra pradesh": "Andhra Pradesh",
    "Andhra Pradesh": "Andhra Pradesh"
}

df["state"] = df["state"].replace(state_mapping)

df = df.drop(columns=["date", "district", "pincode", "age_0_5"], errors="ignore")

clean_summary = df.groupby("state")[["age_5_17", "age_18_greater"]].sum().reset_index()

clean_summary.rename(columns={"age_18_greater": "age_17_"}, inplace=True)

clean_summary.to_csv("statewise_age_summary.csv", index=False)

print("Cleaned file 'statewise_age_summary.csv' created with official names, unique states, and summed ages")
# Out:
# Cleaned file 'statewise_age_summary.csv' created with official names, unique states, and summed ages

# %%
import pandas as pd

# Step 1: Read the dataset
df = pd.read_csv("combined_data.csv")

# Step 2: Normalize state/UT names
state_mapping = {
    "Orissa": "Odisha",
    "ODISHA": "Odisha",
    "odisha": "Odisha",
    "Tamilnadu": "Tamil Nadu",
    "Tamilnadu ": "Tamil Nadu",
    "Tamil Nadu": "Tamil Nadu",
    "Jammu & Kashmir": "Jammu and Kashmir",
    "Jammu And Kashmir": "Jammu and Kashmir",
    "Jammu and Kashmir": "Jammu and Kashmir",
    "Uttaranchal": "Uttarakhand",
    "West  Bengal": "West Bengal",
    "West Bangal": "West Bengal",
    "West bengal": "West Bengal",
    "WEST BENGAL": "West Bengal",
    "WESTBENGAL": "West Bengal",
    "west Bengal": "West Bengal",
    "Westbengal": "West Bengal",
    "Daman & Diu": "Dadra and Nagar Haveli and Daman and Diu",
    "Daman and Diu": "Dadra and Nagar Haveli and Daman and Diu",
    "Dadra & Nagar Haveli": "Dadra and Nagar Haveli and Daman and Diu",
    "Dadra and Nagar Haveli": "Dadra and Nagar Haveli and Daman and Diu",
    "dadar nager hawali and daman diu": "Dadra and Nagar Haveli and Daman and Diu",
    "Pondicherry": "Puducherry",
    "Puducherry": "Puducherry",
    "Andaman & Nicobar Islands": "Andaman and Nicobar Islands",
    "Andaman and Nicobar Islands": "Andaman and Nicobar Islands",
    "Delhi": "Delhi",
    "Chhatisgarh": "Chhattisgarh",
    "andhra pradesh": "Andhra Pradesh",
    "Andhra Pradesh": "Andhra Pradesh"
}

df["state"] = df["state"].replace(state_mapping)

# Step 3: Drop unwanted columns
df = df.drop(columns=["date", "district", "pincode","age_0_5"], errors="ignore")

# Step 4: Aggregate by unique state/UT and sum age columns
clean_summary = df.groupby("state")[["age_5_17", "age_18_greater"]].sum().reset_index()

# Step 5: Export cleaned dataset
clean_summary.to_csv("cleaned_enrolement.csv", index=False)

print("Cleaned file 'cleaned_enrolement.csv' ")
# Out:
# Cleaned file 'cleaned_enrolement.csv'

# %%
import pandas as pd

# Step 1: Read the dataset
df = pd.read_csv("cleaned_enrolement.csv")

# Step 2: Normalize state/UT names
state_mapping = {
    "dader nager hawali": "Dadra and Nagar Haveli and Daman and Diu",
    
    "the dader nager hawalli": "Dadra and Nagar Haveli and Daman and Diu",
    "Dadra & Nagar Haveli": "Dadra and Nagar Haveli and Daman and Diu",
    "Dadra and Nagar Haveli": "Dadra and Nagar Haveli and Daman and Diu",
    "Daman & Diu": "Dadra and Nagar Haveli and Daman and Diu",
    "Daman and Diu": "Dadra and Nagar Haveli and Daman and Diu"
}

df["state"] = df["state"].replace(state_mapping)

# Step 3: Remove one unwanted row (example: first row if it's dummy)
df = df.iloc[1:]   # removes the first row

# Step 4: Aggregate by official state/UT names
clean_summary = df.groupby("state")[["age_5_17", "age_18_greater"]].sum().reset_index()

# Step 5: Export cleaned dataset
clean_summary.to_csv("cleaned_age_by_state.csv", index=False)

print("✅ Cleaned file 'cleaned_age_by_state.csv' ")
# Out:
# ✅ Cleaned file 'cleaned_age_by_state.csv'
