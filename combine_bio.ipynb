# %%
import pandas as pd
import glob

folder_path = r"C:\Users\Tushar\anaconda_projects\Pandas\UIDAI HACKTHON\Hackthon\api_data_aadhar_biometric"

csv_files = glob.glob(folder_path + "/*.csv")

df_list = [pd.read_csv(file) for file in csv_files]
combined_df = pd.concat(df_list, ignore_index=True)

combined_df.to_csv("combined_bio_data.csv", index=False)

print("All files merged and saved as combined_bio_data.csv")
# Out:
# All files merged and saved as combined_bio_data.csv

# %%
import pandas as pd

# Step 1: Read the uploaded CSV file
df = pd.read_csv("combined_bio_data.csv")

# Step 2: Define mapping of variations to official names
state_mapping = {
    "Orissa": "Odisha",
    "ODISHA": "Odisha",
    "odisha": "Odisha",
    "Tamilnadu": "Tamil Nadu",
    "Tamilnadu ": "Tamil Nadu",
    "Tamil Nadu": "Tamil Nadu",
    "Jammu & Kashmir": "Jammu and Kashmir",
    "Jammu and Kashmir": "Jammu and Kashmir",
    "Uttaranchal": "Uttarakhand",
    "West  Bengal": "West Bengal",
    "West Bangal": "West Bengal",
    "West bengal": "West Bengal",
    "WEST BENGAL": "West Bengal",
    "WESTBENGAL": "West Bengal",
    "west Bengal" : "West Bengal",
    "Westbengal": "West Bengal",
    "Daman & Diu": "Dadra and Nagar Haveli and Daman and Diu",
    "Daman and Diu" : "Dadra and Nagar Haveli and Daman and Diu",
    "Daman and Diu": "Dadra and Nagar Haveli and Daman and Diu",
    "Dadra & Nagar Haveli": "Dadra and Nagar Haveli and Daman and Diu",
    "Dadra and Nagar Haveli": "Dadra and Nagar Haveli and Daman and Diu",
    "Dadra and Nagar Haveli and Daman and Diu": "Dadra and Nagar Haveli and Daman and Diu",
    "Pondicherry": "Puducherry",
    "Puducherry": "Puducherry",
    "Andaman & Nicobar Islands": "Andaman and Nicobar Islands",
    "Andaman and Nicobar Islands": "Andaman and Nicobar Islands",
    "Delhi": "Delhi",
    "Chhatisgarh": "Chhattisgarh",
    "andhra pradesh" : "Andhra Pradesh",
    "andhra pradesh": "Andhra Pradesh",
    "Andhra Pradesh": "Andhra Pradesh",
    "dadar nager hawali and daman diu": "Dadra and Nagar Haveli and Daman and Diu",
    "Dadra and Nagar Haveli and Daman and Diu": "Dadra and Nagar Haveli and Daman and Diu",
    "West Bangal": "West Bengal",
    "West Bengal": "West Bengal"
}

df["state"] = df["state"].replace(state_mapping)

summary = df.groupby("state", as_index=False)[["bio_age_5_17", "bio_age_17_"]].sum()

summary.rename(columns={
    "bio_age_5_17": "bio_age_5_17",
    "bio_age_17_": "bio_age_17_"
}, inplace=True)

# Export to new CSV
summary.to_csv("statewise_bio_age_.csv", index=False)
